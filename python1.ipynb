# %% [markdown]
# <a href="https://colab.research.google.com/github/AranMadrid/python1/blob/main/python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#definir variables
nombre =(input("¿Cual es tu nombre? "))
edad = int(input("¿Cual es tu edad? "))
print(f"Hola {nombre} tienes {edad} años")
# Out:
# ¿Cual es tu nombre? aran
# ¿Cual es tu edad? 40
# Hola aran tienes 40 años

# %%
def saludar(nombre):
  return "hola " + nombre+ " bienvenida al taller de python"
saludar(nombre)
# Out:
# 'hola aran bienvenida al taller de python'

# %%
#definimos una funion para determinar si el usuario
#es mayor de edad
def es_mayor_de_edad(edad):
  if edad >= 18:
    return "eres mayor de edad"
  else:
    return "eres menor de edad"
print(es_mayor_de_edad(edad))
# Out:
# eres mayor de edad

# %%
for recorrer in range(1,5):
  print(recorrer)
# Out:
# 1
# 2
# 3
# 4
